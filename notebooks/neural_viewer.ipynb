# %%
import sys
sys.path.append('.')  # Add current directory to path

from src.viewer.arc_notebook_viewer import ARCNotebookViewer
from src.nn.evaluator import ARCEvaluator
import matplotlib.pyplot as plt

# %%
checkpoint_pth = "../train/runs/2025-10-11_19-22-40/checkpoints/last.ckpt"
checkpoint_pth = "../checkpoints/last.ckpt"
device = "cpu"
data_dir = "../data"
batch_size = 16

# %%
# Configure matplotlib for better notebook display
plt.rcParams['figure.dpi'] = 100
plt.rcParams['figure.facecolor'] = 'white'
viewer = ARCNotebookViewer(data_dir=data_dir)
viewer.load_data()
# Out:
# ✓ Loaded arc-agi_training_challenges.json: 1000 tasks
# ✓ Loaded arc-agi_training_solutions.json: 1000 tasks
# ✓ Loaded arc-agi_evaluation_challenges.json: 120 tasks
# ✓ Loaded arc-agi_evaluation_solutions.json: 120 tasks
# ✓ Loaded arc-agi_test_challenges.json: 240 tasks
# {'training_challenges': 1000,
#  'training_solutions': 1000,
#  'evaluation_challenges': 120,
#  'evaluation_solutions': 120,
#  'test_challenges': 240}

# %%
evaluator = ARCEvaluator(
        checkpoint_path=checkpoint_pth,
        data_dir=data_dir,
        batch_size=batch_size,
        device=device
    )
# Out:
# Using device: cpu
# Loading model from ../checkpoints/last.ckpt and device=cpu
# Model loaded: TRMModule
# Loading evaluation data from ../data
# Loaded 120 evaluation tasks

# %%
viewer.visualize_model_predictions(evaluator.model, show_only_correct=False, task_ids=['da515329'], dataset='validation')
# Out:
# 📊 Task 20a9e565 - TRMModule: ✗ 0/2 (0%)
# ------------------------------------------------------------
#
# ============================================================
# 📊 Summary: 0/1 tasks completely correct (0.0%)
# ============================================================
# {'total_shown': 1,
#  'total_correct': 0,
#  'accuracy': 0.0,
#  'task_results': [{'task_id': '20a9e565',
#    'correct': False,
#    'num_correct': 0,
#    'num_total': 2}]}

# %%
viewer.show_task(dataset='validation')
# Out:
# 📊 Task Statistics for 67e490f4:
#   • Training examples: 2
#   • Test examples: 1
#   • First training input shape: (30, 30)
#   • First training output shape: (11, 11)
#   • Colors used in inputs: [1, 2, 3, 4, 5, 6, 7, 8, 9]
#   • Colors used in outputs: [1, 3, 4, 5, 7, 8, 9]
